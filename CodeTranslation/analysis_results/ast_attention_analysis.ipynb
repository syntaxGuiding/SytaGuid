# %%
import pickle
import matplotlib.pyplot as plt
import sklearn
from matplotlib import cm
from sklearn import manifold
import seaborn as sns
import numpy as np

# %%
# load pickled data
ast_attentions = pickle.load(open("AST_attentions_avg.pkl", "rb"))

# %%
syntax_list = ['else', 
            'if_statement', 
            'method_declaration', 
            'class_declaration', 
            'constructor_declaration']

BLUE = "#3498db"
RED = "#e74c3c"

# %%
def get_data_points(head_data):
  xs, ys, avgs = [], [], []
  for layer in range(12):
    for head in range(12):
      ys.append(head_data[layer][head])
      xs.append(1 + layer)
    avgs.append(head_data[layer].mean())
  return xs, ys, avgs

def add_line(key, ax, color, label, linestyle,marker, plot_avgs=True):
  xs, ys, avgs = get_data_points(avg_attns[key])
  ax.scatter(xs, ys, s=25, label=label, color=color, marker=marker)
  if plot_avgs:
    ax.plot(1 + np.arange(len(avgs)), avgs, color=color, linestyle=linestyle)
  ax.legend(loc=1, fontsize=12, frameon=True, prop={'weight':'bold'})
  ax.set_xlabel("Layer")
  ax.set_ylabel("Avg. Attention")

# %%
avg_attns = {}

for key in ast_attentions:
    avg_attns[key] = np.array(ast_attentions[key])

# %%
avg_attns.keys()
# Out:
# dict_keys(['If_else_wrong', 'If_else_correct', 'method_signature_correct', 'method_signatures_wrong', 'return_statements_correct', 'return_statements_wrong', 'while_statements_correct', 'while_statements_wrong'])

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.0005, 0.0025)
ax.set_xlim(0, 13)

for key, color, label, style, marker in [ ("If_else_correct", BLUE, "If_else_statement(Correct)", '-', 'v'), 
                                          ("If_else_wrong", RED, "If_else_statement(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.002)
ax.set_xlim(0, 13)
for key, color, label, style, marker  in [ ("method_signature_correct", BLUE, "Method_signature(Correct)", '-', 'v'),
                           ("method_signatures_wrong", RED, "Method_signature(Wrong)", '--', 'o')
                           ]:
  add_line(key, ax, color, label, style, marker )

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0, 0.0050)
ax.set_xlim(0, 13)

for key,  color, label, style, marker in [ ("return_statements_correct", BLUE, "Return_statement(Correct)", '-', 'v'), 
                           ("return_statements_wrong", RED, "Return_statement(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0, 0.0050)
ax.set_xlim(0, 13)

for key,  color, label, style, marker  in [ ("while_statements_correct", BLUE, "While_statement(Correct)", '-', 'v'),
                      ("while_statements_wrong", RED, "While_statement(Wrong)",  '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
# pickle the data 
pickle.dump(avg_attns, open("AST_attentions_avg.pkl", "wb"))
