# %%
import json
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import pickle

# %%
def get_data_points(head_data):
  xs, ys, avgs = [], [], []
  for layer in range(12):
    for head in range(12):
      ys.append(head_data[layer][head])
      xs.append(1 + layer)
    avgs.append(head_data[layer].mean())
  return xs, ys, avgs

def add_line(key, ax, color, label, linestyle,marker, plot_avgs=True):
  xs, ys, avgs = get_data_points(avg_attns[key])
  ax.scatter(xs, ys, s=25, label=label, color=color, marker=marker)
  if plot_avgs:
    ax.plot(1 + np.arange(len(avgs)), avgs, color=color, linestyle=linestyle)
  ax.legend(loc=1, fontsize=12, frameon=True, prop={'weight':'bold'})
  ax.set_xlabel("Layer")
  ax.set_ylabel("Avg. Attention")

# %%
syntax_list = ['annotation', 'basictype', 'boolean', 
               'identifier',  'keyword', 'modifier', 
               'operator', 'separator', 'string']

BLUE = "#3498db"
RED = "#e74c3c"

# %%
correct = pickle.load(open("Correct_Syntax_avg.pkl", "rb"))
wrong = pickle.load(open("Wrong_Syntax_avg.pkl", "rb"))

# %%
avg_attns = {}
a = list(correct.keys())
for key in a:
    avg_attns[key+'_correct'] = correct[key]
    avg_attns[key+'_wrong'] = wrong[key]

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.004)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("basictype_correct", BLUE, "DataType(Correct)", '-', 'v'),
                                ("basictype_wrong", RED, "DataType(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.009)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("boolean_correct", BLUE, "Boolean(Correct)", '-', 'v'),
                                ("boolean_wrong", RED, "Boolean(wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.0015, 0.004)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("identifier_correct", BLUE, "Identifier(Correct)", '-', 'v'),
                           ("identifier_wrong", RED, "Identifier(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.005)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("keyword_correct", BLUE, "Keyword(Correct)", '-', 'v'),
                                          ("keyword_wrong", RED, "Keyword(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.006)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("modifier_correct", BLUE, "Modifier(Correct)", '-', 'v'),
                                          ("modifier_wrong", RED, "Modifier(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.004)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("operator_correct", BLUE, "Operator(Correct)", '-', 'v'),
                                          ("operator_wrong", RED, "Operator(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.002, 0.0055)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("separator_correct", BLUE, "Separator(Correct)", '-', 'v'),
                                          ("separator_wrong", RED, "Separator(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)

# %%
plt.figure(figsize=(6, 11))
ax = plt.subplot(2, 1, 1)
ax.set_ylim(0.001, 0.006)
ax.set_xlim(0, 13)
for key, color, label, style, marker in [ ("string_correct", BLUE, "String(Correct)", '-', 'v'),
                                          ("string_wrong", RED, "String(Wrong)", '--', 'o')]:
  add_line(key, ax, color, label, style, marker)
